# %%
import kagglehub

path = kagglehub.dataset_download("bulter22/airline-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\HP\.cache\kagglehub\datasets\bulter22\airline-data\versions\2

# %%
import pandas as pd
import os

path = "C:/Users/HP/.cache/kagglehub/datasets/bulter22/airline-data/versions/2"
print(os.path.exists(os.path.join(path, "airlines.csv")))
path=os.path.join(path, "airlines.csv")
# Out:
# True

# %%
import pandas as pd
df = pd.read_csv(
    r"C:\Users\HP\OneDrive\AppData\Desktop\!!74 pr\data\airlines.csv",
    encoding="latin1",
    nrows=12300000
)

# %%
x=df['Dest'].unique()
y=df['Origin'].unique()
x.__len__()
# Out:
# 343

# %%
y.__len__()
# Out:
# 343
